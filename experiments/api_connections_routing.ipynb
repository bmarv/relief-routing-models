# %% [markdown]
# # API Connections for Routing
# Investigation of the following open-access apis:
# * https://openrouteservice.org/dev/#/api-docs/v2/
# * https://earthquake.usgs.gov/earthquakes/feed/v1.0/geojson.php

# %% [markdown]
# ## OpenRouteService

# %% [markdown]
# * Data Sources
#     * OpenStreetMap
#     * Crowdsourced updates
# * Availability
#     * opensource
#     * free of charge
# * available features
#     * multi-modal routing (cars, bikes, walking)
#     * time-distance matrix for selecting a favorite among multiple options
# * optimizations
#     * incorporated methods for tsp, vrp
# * interesting oss clients:
#     * disaster maps client: disaster management, updated with information
#     * classic maps client / new maps client: route planning

# %%
from dotenv import dotenv_values
import requests
import folium
import pandas as pd

# %%
import openrouteservice as ors

# %%
base_path = 'https://api.openrouteservice.org/'
profile_car = 'driving-car'

# %%
# environment vars
config = dotenv_values("../.env")
ors_api_key = config['ORS_API_KEY']

# %% [markdown]
# ### GET Endpoints

# %%
# endpoints
directions_endpoint = 'v2/directions/'
geocode_search_endpoint = 'geocode/search'

# %%
r1_params = {
    'start':  '8.681495,49.41461',
    'end': '8.687872,49.420318'
}

# %%
r1_params_string = ''
for k, v in r1_params.items():
    r1_params_string += f'&{k}={v}'
r1_params_string
# Out:
# '&start=8.681495,49.41461&end=8.687872,49.420318'

# %%
r = requests.get(
    f'{base_path}{directions_endpoint}{profile_car}?api_key={ors_api_key}{r1_params_string}'
)

# %%
r2_params = {
    'text': 'Namibian Brewery'
}

# %%
r2_params_string = ''
for k,v in r2_params.items():
    r2_params_string += f'&{k}={v}'

# %%
r2 = requests.get(
    f'{base_path}{geocode_search_endpoint}?api_key={ors_api_key}{r2_params_string}'
)

# %%
r2.json()
# Out:
# {'geocoding': {'version': '0.2',
#   'attribution': 'https://openrouteservice.org/terms-of-service/#attribution-geocode',
#   'query': {'text': 'Namibian Brewery',
#    'size': 10,
#    'layers': ['venue',
#     'street',
#     'country',
#     'macroregion',
#     'region',
#     'county',
#     'localadmin',
#     'locality',
#     'borough',
#     'neighbourhood',
#     'continent',
#     'empire',
#     'dependency',
#     'macrocounty',
#     'macrohood',
#     'microhood',
#     'disputed',
#     'postalcode',
#     'ocean',
#     'marinearea'],
#    'private': False,
#    'lang': {'name': 'English',
#     'iso6391': 'en',
#     'iso6393': 'eng',
#     'via': 'default',
#     'defaulted': True},
#    'querySize': 20,
#    'parser': 'pelias',
#    'parsed_text': {'subject': 'Namibian Brewery',
#     'venue': 'Namibian Brewery'}},
#   'warnings': ["performance optimization: excluding 'address' layer"],
#   'engine': {'name': 'Pelias', 'author': 'Mapzen', 'version': '1.0'},
#   'timestamp': 1687179737734},
#  'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [16.646344, -20.459019]},
#    'properties': {'id': 'node/4684870705',
#     'gid': 'openstreetmap:venue:node/4684870705',
#     'layer': 'venue',
#     'source': 'openstreetmap',
#     'source_id': 'node/4684870705',
#     'name': 'Namibian Brewery',
#     'confidence': 1,
#     'match_type': 'exact',
#     'accuracy': 'point',
#     'country': 'Namibia',
#     'country_gid': 'whosonfirst:country:85632535',
#     'country_a': 'NAM',
#     'region': 'Otjozondjupa',
#     'region_gid': 'whosonfirst:region:85675217',
#     'region_a': 'OD',
#     'county': 'Otjiwarongo',
#     'county_gid': 'whosonfirst:county:421186163',
#     'county_a': 'OW',
#     'continent': 'Africa',
#     'continent_gid': 'whosonfirst:continent:102191573',
#     'label': 'Namibian Brewery, OD, Namibia'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [17.084177, -22.56012]},
#    'properties': {'id': 'node/811183175',
#     'gid': 'openstreetmap:venue:node/811183175',
#     'layer': 'venue',
#     'source': 'openstreetmap',
#     'source_id': 'node/811183175',
#     'name': 'Namibian Police',
#     'confidence': 1,
#     'match_type': 'exact',
#     'accuracy': 'point',
#     'country': 'Namibia',
#     'country_gid': 'whosonfirst:country:85632535',
#     'country_a': 'NAM',
#     'region': 'Khomas',
#     'region_gid': 'whosonfirst:region:85675205',
#     'region_a': 'KH',
#     'locality': 'Windhoek',
#     'locality_gid': 'whosonfirst:locality:1141909361',
#     'continent': 'Africa',
#     'continent_gid': 'whosonfirst:continent:102191573',
#     'label': 'Namibian Police, Windhoek, KH, Namibia',
#     'addendum': {'osm': {'operator': 'GRN'}}}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [17.082562, -22.561998]},
#    'properties': {'id': 'node/8830507327',
#     'gid': 'openstreetmap:venue:node/8830507327',
#     'layer': 'venue',
#     'source': 'openstreetmap',
#     'source_id': 'node/8830507327',
#     'name': 'The Namibian',
#     'confidence': 1,
#     'match_type': 'exact',
#     'accuracy': 'point',
#     'country': 'Namibia',
#     'country_gid': 'whosonfirst:country:85632535',
#     'country_a': 'NAM',
#     'region': 'Khomas',
#     'region_gid': 'whosonfirst:region:85675205',
#     'region_a': 'KH',
#     'locality': 'Windhoek',
#     'locality_gid': 'whosonfirst:locality:1141909361',
#     'continent': 'Africa',
#     'continent_gid': 'whosonfirst:continent:102191573',
#     'label': 'The Namibian, Windhoek, KH, Namibia',
#     'addendum': {'osm': {'website': 'https://www.namibian.com.na/',
#       'phone': '+264 61 279600'}}}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [17.087509, -22.579487]},
#    'properties': {'id': 'way/917792955',
#     'gid': 'openstreetmap:venue:way/917792955',
#     'layer': 'venue',
#     'source': 'openstreetmap',
#     'source_id': 'way/917792955',
#     'name': 'Namibian Police Force Headquarter',
#     'street': 'Julius Nyerere Street',
#     'confidence': 1,
#     'match_type': 'exact',
#     'accuracy': 'point',
#     'country': 'Namibia',
#     'country_gid': 'whosonfirst:country:85632535',
#     'country_a': 'NAM',
#     'region': 'Khomas',
#     'region_gid': 'whosonfirst:region:85675205',
#     'region_a': 'KH',
#     'locality': 'Windhoek',
#     'locality_gid': 'whosonfirst:locality:1141909361',
#     'continent': 'Africa',
#     'continent_gid': 'whosonfirst:continent:102191573',
#     'label': 'Namibian Police Force Headquarter, Windhoek, KH, Namibia',
#     'addendum': {'osm': {'wikidata': 'Q2101659',
#       'wikipedia': 'en:Namibian Police Force',
#       'operator': 'NAMPOL',
#       'website': 'https://nampol.gov.na'}}},
#    'bbox': [17.086516, -22.5801036, 17.0883757, -22.5786245]},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [14.516254, -22.94544]},
#    'properties': {'id': 'node/9966039074',
#     'gid': 'openstreetmap:venue:node/9966039074',
#     'layer': 'venue',
#     'source': 'openstreetmap',
#     'source_id': 'node/9966039074',
#     'name': 'Namibian Pie Company',
#     'confidence': 1,
#     'match_type': 'exact',
#     'accuracy': 'point',
#     'country': 'Namibia',
#     'country_gid': 'whosonfirst:country:85632535',
#     'country_a': 'NAM',
#     'region': 'Erongo',
#     'region_gid': 'whosonfirst:region:85675213',
#     'region_a': 'ER',
#     'county': 'Walvis Bay Urban',
#     'county_gid': 'whosonfirst:county:890443131',
#     'county_a': 'WU',
#     'continent': 'Africa',
#     'continent_gid': 'whosonfirst:continent:102191573',
#     'label': 'Namibian Pie Company, ER, Namibia',
#     'addendum': {'osm': {'opening_hours': 'Mo-Fr 07:00-04:00'}}}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [19.84855, -28.11759]},
#    'properties': {'id': 'node/6947262685',
#     'gid': 'openstreetmap:venue:node/6947262685',
#     'layer': 'venue',
#     'source': 'openstreetmap',
#     'source_id': 'node/6947262685',
#     'name': 'Namibian Border Control',
#     'confidence': 1,
#     'match_type': 'exact',
#     'accuracy': 'point',
#     'country': 'Namibia',
#     'country_gid': 'whosonfirst:country:85632535',
#     'country_a': 'NAM',
#     'region': 'Karas',
#     'region_gid': 'whosonfirst:region:85675195',
#     'region_a': 'KA',
#     'county': 'Karas',
#     'county_gid': 'whosonfirst:county:1108785097',
#     'county_a': 'KA',
#     'continent': 'Africa',
#     'continent_gid': 'whosonfirst:continent:102191573',
#     'label': 'Namibian Border Control, KA, Namibia'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [16.645597, -20.467272]},
#    'properties': {'id': 'way/473387616',
#     'gid': 'openstreetmap:venue:way/473387616',
#     'layer': 'venue',
#     'source': 'openstreetmap',
#     'source_id': 'way/473387616',
#     'name': 'Museum of Namibian Fashion',
#     'housenumber': 'Erf 235',
#     'street': 'Park Street',
#     'postalcode': '12001',
#     'confidence': 1,
#     'match_type': 'exact',
#     'accuracy': 'point',
#     'country': 'Namibia',
#     'country_gid': 'whosonfirst:country:85632535',
#     'country_a': 'NAM',
#     'region': 'Otjozondjupa',
#     'region_gid': 'whosonfirst:region:85675217',
#     'region_a': 'OD',
#     'county': 'Otjiwarongo',
#     'county_gid': 'whosonfirst:county:421186163',
#     'county_a': 'OW',
#     'continent': 'Africa',
#     'continent_gid': 'whosonfirst:continent:102191573',
#     'label': 'Museum of Namibian Fashion, OD, Namibia',
#     'addendum': {'osm': {'website': 'https://www.namibianfashion.com/'}}},
#    'bbox': [16.6455166, -20.467347, 16.6456484, -20.4671985]},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [19.848413, -28.11896]},
#    'properties': {'id': 'way/1088009857',
#     'gid': 'openstreetmap:venue:way/1088009857',
#     'layer': 'venue',
#     'source': 'openstreetmap',
#     'source_id': 'way/1088009857',
#     'name': 'Namibian Clearing Agency',
#     'confidence': 1,
#     'match_type': 'exact',
#     'accuracy': 'point',
#     'country': 'Namibia',
#     'country_gid': 'whosonfirst:country:85632535',
#     'country_a': 'NAM',
#     'region': 'Karas',
#     'region_gid': 'whosonfirst:region:85675195',
#     'region_a': 'KA',
#     'county': 'Karas',
#     'county_gid': 'whosonfirst:county:1108785097',
#     'county_a': 'KA',
#     'continent': 'Africa',
#     'continent_gid': 'whosonfirst:continent:102191573',
#     'label': 'Namibian Clearing Agency, KA, Namibia',
#     'addendum': {'osm': {'website': 'https://namibianclearingagency.com/'}}},
#    'bbox': [19.8479517, -28.1194071, 19.8488011, -28.1186403]},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [17.090719, -22.541317]},
#    'properties': {'id': 'node/6720040964',
#     'gid': 'openstreetmap:venue:node/6720040964',
#     'layer': 'venue',
#     'source': 'openstreetmap',
#     'source_id': 'node/6720040964',
#     'name': 'Namibian Breastmilk Bank',
#     'confidence': 1,
#     'match_type': 'exact',
#     'accuracy': 'point',
#     'country': 'Namibia',
#     'country_gid': 'whosonfirst:country:85632535',
#     'country_a': 'NAM',
#     'region': 'Khomas',
#     'region_gid': 'whosonfirst:region:85675205',
#     'region_a': 'KH',
#     'locality': 'Windhoek',
#     'locality_gid': 'whosonfirst:locality:1141909361',
#     'continent': 'Africa',
#     'continent_gid': 'whosonfirst:continent:102191573',
#     'label': 'Namibian Breastmilk Bank, Windhoek, KH, Namibia',
#     'addendum': {'osm': {'website': 'https://www.nbmb.com.na'}}}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [17.086323, -22.560747]},
#    'properties': {'id': 'way/751007763',
#     'gid': 'openstreetmap:venue:way/751007763',
#     'layer': 'venue',
#     'source': 'openstreetmap',
#     'source_id': 'way/751007763',
#     'name': 'Franco Namibian Cultural Centre',
#     'housenumber': '118',
#     'street': 'Robert Mugabe Avenue',
#     'confidence': 1,
#     'match_type': 'exact',
#     'accuracy': 'point',
#     'country': 'Namibia',
#     'country_gid': 'whosonfirst:country:85632535',
#     'country_a': 'NAM',
#     'region': 'Khomas',
#     'region_gid': 'whosonfirst:region:85675205',
#     'region_a': 'KH',
#     'locality': 'Windhoek',
#     'locality_gid': 'whosonfirst:locality:1141909361',
#     'continent': 'Africa',
#     'continent_gid': 'whosonfirst:continent:102191573',
#     'label': 'Franco Namibian Cultural Centre, Windhoek, KH, Namibia',
#     'addendum': {'osm': {'website': 'http://www.fncc.org.na/'}}},
#    'bbox': [17.0860616, -22.56081, 17.0865843, -22.5606842]}],
#  'bbox': [14.516254, -28.1194071, 19.8488011, -20.459019]}

# %%
def get_request_for_ors(
    endpoint: str,
    parameters: dict,
    profile = None,
    json_ize = True
):
    params_string = ''
    for k, v in parameters.items():
        params_string += f'&{k}={v}'
    params_string
    if profile is not None:
        request_url = f'{base_path}{endpoint}{profile}?api_key={ors_api_key}{params_string}'
    else:
        request_url = f'{base_path}{endpoint}?api_key={ors_api_key}{params_string}'
    r = requests.get(request_url)
    if json_ize:
        return r.json()
    return r

# %%
r = get_request_for_ors(
    endpoint= directions_endpoint,
    parameters= r1_params,
    profile= profile_car,
    json_ize= True
)

# %%
r['features'][0]['geometry']['coordinates']
# Out:
# [[8.681496, 49.414601],
#  [8.68147, 49.414599],
#  [8.681488, 49.41465],
#  [8.681423, 49.415698],
#  [8.681423, 49.415746],
#  [8.681427, 49.415802],
#  [8.681509, 49.416087],
#  [8.681656, 49.41659],
#  [8.681825, 49.417081],
#  [8.681875, 49.417287],
#  [8.681881, 49.417392],
#  [8.682057, 49.417393],
#  [8.682107, 49.41739],
#  [8.682461, 49.417389],
#  [8.682676, 49.417387],
#  [8.683379, 49.41738],
#  [8.683595, 49.417372],
#  [8.683709, 49.417368],
#  [8.685294, 49.417365],
#  [8.685359, 49.417365],
#  [8.685442, 49.417365],
#  [8.685713, 49.41737],
#  [8.686407, 49.417365],
#  [8.686717, 49.417366],
#  [8.686806, 49.417365],
#  [8.68703, 49.41736],
#  [8.687156, 49.417357],
#  [8.687376, 49.417353],
#  [8.687466, 49.417351],
#  [8.687547, 49.417349],
#  [8.688256, 49.417361],
#  [8.688802, 49.417381],
#  [8.688793, 49.417434],
#  [8.68871, 49.418194],
#  [8.688647, 49.418464],
#  [8.688539, 49.418963],
#  [8.688398, 49.41963],
#  [8.690104, 49.419828],
#  [8.690123, 49.419833],
#  [8.689854, 49.420216],
#  [8.689652, 49.420514],
#  [8.68963, 49.42051],
#  [8.688601, 49.420393],
#  [8.687872, 49.420318]]

# %%
reversed_coordinates = [list(reversed(coord))
                            for coord 
                            in r['features'][0]['geometry']['coordinates']
                        ]
reversed_coordinates
# Out:
# [[49.414601, 8.681496],
#  [49.414599, 8.68147],
#  [49.41465, 8.681488],
#  [49.415698, 8.681423],
#  [49.415746, 8.681423],
#  [49.415802, 8.681427],
#  [49.416087, 8.681509],
#  [49.41659, 8.681656],
#  [49.417081, 8.681825],
#  [49.417287, 8.681875],
#  [49.417392, 8.681881],
#  [49.417393, 8.682057],
#  [49.41739, 8.682107],
#  [49.417389, 8.682461],
#  [49.417387, 8.682676],
#  [49.41738, 8.683379],
#  [49.417372, 8.683595],
#  [49.417368, 8.683709],
#  [49.417365, 8.685294],
#  [49.417365, 8.685359],
#  [49.417365, 8.685442],
#  [49.41737, 8.685713],
#  [49.417365, 8.686407],
#  [49.417366, 8.686717],
#  [49.417365, 8.686806],
#  [49.41736, 8.68703],
#  [49.417357, 8.687156],
#  [49.417353, 8.687376],
#  [49.417351, 8.687466],
#  [49.417349, 8.687547],
#  [49.417361, 8.688256],
#  [49.417381, 8.688802],
#  [49.417434, 8.688793],
#  [49.418194, 8.68871],
#  [49.418464, 8.688647],
#  [49.418963, 8.688539],
#  [49.41963, 8.688398],
#  [49.419828, 8.690104],
#  [49.419833, 8.690123],
#  [49.420216, 8.689854],
#  [49.420514, 8.689652],
#  [49.42051, 8.68963],
#  [49.420393, 8.688601],
#  [49.420318, 8.687872]]

# %%
r['features'][0]['geometry']['coordinates']
# Out:
# [[8.681496, 49.414601],
#  [8.68147, 49.414599],
#  [8.681488, 49.41465],
#  [8.681423, 49.415698],
#  [8.681423, 49.415746],
#  [8.681427, 49.415802],
#  [8.681509, 49.416087],
#  [8.681656, 49.41659],
#  [8.681825, 49.417081],
#  [8.681875, 49.417287],
#  [8.681881, 49.417392],
#  [8.682057, 49.417393],
#  [8.682107, 49.41739],
#  [8.682461, 49.417389],
#  [8.682676, 49.417387],
#  [8.683379, 49.41738],
#  [8.683595, 49.417372],
#  [8.683709, 49.417368],
#  [8.685294, 49.417365],
#  [8.685359, 49.417365],
#  [8.685442, 49.417365],
#  [8.685713, 49.41737],
#  [8.686407, 49.417365],
#  [8.686717, 49.417366],
#  [8.686806, 49.417365],
#  [8.68703, 49.41736],
#  [8.687156, 49.417357],
#  [8.687376, 49.417353],
#  [8.687466, 49.417351],
#  [8.687547, 49.417349],
#  [8.688256, 49.417361],
#  [8.688802, 49.417381],
#  [8.688793, 49.417434],
#  [8.68871, 49.418194],
#  [8.688647, 49.418464],
#  [8.688539, 49.418963],
#  [8.688398, 49.41963],
#  [8.690104, 49.419828],
#  [8.690123, 49.419833],
#  [8.689854, 49.420216],
#  [8.689652, 49.420514],
#  [8.68963, 49.42051],
#  [8.688601, 49.420393],
#  [8.687872, 49.420318]]

# %%
m = folium.Map(location= (r['features'][0]['bbox'][1], r['features'][0]['bbox'][2]), tiles='cartodbpositron', zoom_start=13)
# m = folium.Map(bounds=r['features'][0]['bbox'])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6358a99452235c6745ba30215a4b3212 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6358a99452235c6745ba30215a4b3212&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6358a99452235c6745ba30215a4b3212 = L.map(
#                 &quot;map_6358a99452235c6745ba30215a4b3212&quot;,
#                 {
#                     center: [49.414599, 8.690123],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38004693f81e5a8002168995507d9c8a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6358a99452235c6745ba30215a4b3212);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
r['features'][0]['bbox']
# Out:
# [8.681423, 49.414599, 8.690123, 49.420514]

# %%
folium.PolyLine(
    locations=reversed_coordinates
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6358a99452235c6745ba30215a4b3212 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6358a99452235c6745ba30215a4b3212&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6358a99452235c6745ba30215a4b3212 = L.map(
#                 &quot;map_6358a99452235c6745ba30215a4b3212&quot;,
#                 {
#                     center: [49.414599, 8.690123],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38004693f81e5a8002168995507d9c8a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6358a99452235c6745ba30215a4b3212);
#
#
#             var poly_line_8927cee3dda4f6f56035a3a47099922b = L.polyline(
#                 [[49.414601, 8.681496], [49.414599, 8.68147], [49.41465, 8.681488], [49.415698, 8.681423], [49.415746, 8.681423], [49.415802, 8.681427], [49.416087, 8.681509], [49.41659, 8.681656], [49.417081, 8.681825], [49.417287, 8.681875], [49.417392, 8.681881], [49.417393, 8.682057], [49.41739, 8.682107], [49.417389, 8.682461], [49.417387, 8.682676], [49.41738, 8.683379], [49.417372, 8.683595], [49.417368, 8.683709], [49.417365, 8.685294], [49.417365, 8.685359], [49.417365, 8.685442], [49.41737, 8.685713], [49.417365, 8.686407], [49.417366, 8.686717], [49.417365, 8.686806], [49.41736, 8.68703], [49.417357, 8.687156], [49.417353, 8.687376], [49.417351, 8.687466], [49.417349, 8.687547], [49.417361, 8.688256], [49.417381, 8.688802], [49.417434, 8.688793], [49.418194, 8.68871], [49.418464, 8.688647], [49.418963, 8.688539], [49.41963, 8.688398], [49.419828, 8.690104], [49.419833, 8.690123], [49.420216, 8.689854], [49.420514, 8.689652], [49.42051, 8.68963], [49.420393, 8.688601], [49.420318, 8.687872]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6358a99452235c6745ba30215a4b3212);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### using openrouteservice

# %%
client = ors.Client(key=ors_api_key)

# %%
coordinates = [[8.681495,49.41461], [8.687872,49.420318]]

# %%
route = client.directions(
    coordinates=coordinates,
    profile=profile_car,
    format='geojson',
    # options={"avoid_features": ["steps"]},
    validate=False,
)

# %%
m = folium.Map(location= (r['features'][0]['bbox'][1], r['features'][0]['bbox'][2]), tiles='cartodbpositron', zoom_start=13)
reversed_coordinates = [list(reversed(coord))
                            for coord 
                            in r['features'][0]['geometry']['coordinates']
                        ]
folium.PolyLine(
    locations=reversed_coordinates
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4468d2ddc14eb82261760c7e9fa50ac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4468d2ddc14eb82261760c7e9fa50ac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4468d2ddc14eb82261760c7e9fa50ac4 = L.map(
#                 &quot;map_4468d2ddc14eb82261760c7e9fa50ac4&quot;,
#                 {
#                     center: [49.414599, 8.690123],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a90a07d1c9843af22a86235e971e7f1 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4468d2ddc14eb82261760c7e9fa50ac4);
#
#
#             var poly_line_bfa9f4b989cd7a680e044a14235e0dd1 = L.polyline(
#                 [[49.414601, 8.681496], [49.414599, 8.68147], [49.41465, 8.681488], [49.415698, 8.681423], [49.415746, 8.681423], [49.415802, 8.681427], [49.416087, 8.681509], [49.41659, 8.681656], [49.417081, 8.681825], [49.417287, 8.681875], [49.417392, 8.681881], [49.417393, 8.682057], [49.41739, 8.682107], [49.417389, 8.682461], [49.417387, 8.682676], [49.41738, 8.683379], [49.417372, 8.683595], [49.417368, 8.683709], [49.417365, 8.685294], [49.417365, 8.685359], [49.417365, 8.685442], [49.41737, 8.685713], [49.417365, 8.686407], [49.417366, 8.686717], [49.417365, 8.686806], [49.41736, 8.68703], [49.417357, 8.687156], [49.417353, 8.687376], [49.417351, 8.687466], [49.417349, 8.687547], [49.417361, 8.688256], [49.417381, 8.688802], [49.417434, 8.688793], [49.418194, 8.68871], [49.418464, 8.688647], [49.418963, 8.688539], [49.41963, 8.688398], [49.419828, 8.690104], [49.419833, 8.690123], [49.420216, 8.689854], [49.420514, 8.689652], [49.42051, 8.68963], [49.420393, 8.688601], [49.420318, 8.687872]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4468d2ddc14eb82261760c7e9fa50ac4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
route
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'bbox': [8.681423, 49.414599, 8.690123, 49.420514],
#    'type': 'Feature',
#    'properties': {'segments': [{'distance': 1409.2,
#       'duration': 282.0,
#       'steps': [{'distance': 1.9,
#         'duration': 0.5,
#         'type': 11,
#         'instruction': 'Head west on Gerhart-Hauptmann-Straße',
#         'name': 'Gerhart-Hauptmann-Straße',
#         'way_points': [0, 1]},
#        {'distance': 314.0,
#         'duration': 75.3,
#         'type': 3,
#         'instruction': 'Turn sharp right onto Wielandtstraße',
#         'name': 'Wielandtstraße',
#         'way_points': [1, 10]},
#        {'distance': 500.9,
#         'duration': 76.5,
#         'type': 1,
#         'instruction': 'Turn right onto Mönchhofstraße',
#         'name': 'Mönchhofstraße',
#         'way_points': [10, 31]},
#        {'distance': 251.9,
#         'duration': 60.5,
#         'type': 0,
#         'instruction': 'Turn left onto Erwin-Rohde-Straße',
#         'name': 'Erwin-Rohde-Straße',
#         'way_points': [31, 36]},
#        {'distance': 126.8,
#         'duration': 30.4,
#         'type': 1,
#         'instruction': 'Turn right onto Moltkestraße',
#         'name': 'Moltkestraße',
#         'way_points': [36, 38]},
#        {'distance': 83.0,
#         'duration': 7.5,
#         'type': 0,
#         'instruction': 'Turn left onto Handschuhsheimer Landstraße, B 3',
#         'name': 'Handschuhsheimer Landstraße, B 3',
#         'way_points': [38, 40]},
#        {'distance': 130.8,
#         'duration': 31.4,
#         'type': 0,
#         'instruction': 'Turn left onto Roonstraße',
#         'name': 'Roonstraße',
#         'way_points': [40, 43]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at Roonstraße, straight ahead',
#         'name': '-',
#         'way_points': [43, 43]}]}],
#     'summary': {'distance': 1409.2, 'duration': 282.0},
#     'way_points': [0, 43]},
#    'geometry': {'coordinates': [[8.681496, 49.414601],
#      [8.68147, 49.414599],
#      [8.681488, 49.41465],
#      [8.681423, 49.415698],
#      [8.681423, 49.415746],
#      [8.681427, 49.415802],
#      [8.681509, 49.416087],
#      [8.681656, 49.41659],
#      [8.681825, 49.417081],
#      [8.681875, 49.417287],
#      [8.681881, 49.417392],
#      [8.682057, 49.417393],
#      [8.682107, 49.41739],
#      [8.682461, 49.417389],
#      [8.682676, 49.417387],
#      [8.683379, 49.41738],
#      [8.683595, 49.417372],
#      [8.683709, 49.417368],
#      [8.685294, 49.417365],
#      [8.685359, 49.417365],
#      [8.685442, 49.417365],
#      [8.685713, 49.41737],
#      [8.686407, 49.417365],
#      [8.686717, 49.417366],
#      [8.686806, 49.417365],
#      [8.68703, 49.41736],
#      [8.687156, 49.417357],
#      [8.687376, 49.417353],
#      [8.687466, 49.417351],
#      [8.687547, 49.417349],
#      [8.688256, 49.417361],
#      [8.688802, 49.417381],
#      [8.688793, 49.417434],
#      [8.68871, 49.418194],
#      [8.688647, 49.418464],
#      [8.688539, 49.418963],
#      [8.688398, 49.41963],
#      [8.690104, 49.419828],
#      [8.690123, 49.419833],
#      [8.689854, 49.420216],
#      [8.689652, 49.420514],
#      [8.68963, 49.42051],
#      [8.688601, 49.420393],
#      [8.687872, 49.420318]],
#     'type': 'LineString'}}],
#  'bbox': [8.681423, 49.414599, 8.690123, 49.420514],
#  'metadata': {'attribution': 'openrouteservice.org | OpenStreetMap contributors',
#   'service': 'routing',
#   'timestamp': 1686577830339,
#   'query': {'coordinates': [[8.681495, 49.41461], [8.687872, 49.420318]],
#    'profile': 'driving-car',
#    'format': 'geojson'},
#   'engine': {'version': '6.8.1',
#    'build_date': '2023-05-22T14:27:28Z',
#    'graph_date': '2023-06-04T15:57:08Z'}}}

# %% [markdown]
# ## Find round trip
# _via Optimization_

# %%
m = folium.Map(location=[52.521861, 13.40744], tiles='cartodbpositron', zoom_start=13)

# Some coordinates in Berlin
coordinates = [[13.384116, 52.533558], [13.41774, 52.498929], [13.428726, 52.519355], [13.374825, 52.496369], [13.384116, 52.533558]]

# The popup will show the ID in the coordinate list. In a non-optimized waypoint order, the waypoints
# would have been visited from ID 0 to ID 3 sequentially.
for idx, coords in enumerate(coordinates):
    folium.Marker(location=list(reversed(coords)),
                 popup=folium.Popup("ID: {}".format(idx))).add_to(m)

route = client.directions(
    coordinates=coordinates,
    profile='foot-walking',
    format='geojson',
    validate=False,
    optimize_waypoints=True
)

folium.PolyLine(locations=[list(reversed(coord)) 
                           for coord in 
                           route['features'][0]['geometry']['coordinates']]).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_791d3ab10d270449c0f4881446d9c7c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_791d3ab10d270449c0f4881446d9c7c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_791d3ab10d270449c0f4881446d9c7c1 = L.map(
#                 &quot;map_791d3ab10d270449c0f4881446d9c7c1&quot;,
#                 {
#                     center: [52.521861, 13.40744],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d06646675d1d77d1a88a9946cae2b48 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_791d3ab10d270449c0f4881446d9c7c1);
#
#
#             var marker_525112044bdf19d0662460d62c64fdfc = L.marker(
#                 [52.533558, 13.384116],
#                 {}
#             ).addTo(map_791d3ab10d270449c0f4881446d9c7c1);
#
#
#         var popup_1cf3f9c87b4eeb4dd57691f9ee1b423f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2695e5b1a64c3025dee90513cd7bdb14 = $(`&lt;div id=&quot;html_2695e5b1a64c3025dee90513cd7bdb14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 0&lt;/div&gt;`)[0];
#                 popup_1cf3f9c87b4eeb4dd57691f9ee1b423f.setContent(html_2695e5b1a64c3025dee90513cd7bdb14);
#
#
#
#         marker_525112044bdf19d0662460d62c64fdfc.bindPopup(popup_1cf3f9c87b4eeb4dd57691f9ee1b423f)
#         ;
#
#
#
#
#             var marker_4fc0fe3599e28f58ff82147648f08ac5 = L.marker(
#                 [52.498929, 13.41774],
#                 {}
#             ).addTo(map_791d3ab10d270449c0f4881446d9c7c1);
#
#
#         var popup_9663b69db169c7cc601def182f9163ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_55d423ed04a33de6ba70fc38bc819127 = $(`&lt;div id=&quot;html_55d423ed04a33de6ba70fc38bc819127&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 1&lt;/div&gt;`)[0];
#                 popup_9663b69db169c7cc601def182f9163ed.setContent(html_55d423ed04a33de6ba70fc38bc819127);
#
#
#
#         marker_4fc0fe3599e28f58ff82147648f08ac5.bindPopup(popup_9663b69db169c7cc601def182f9163ed)
#         ;
#
#
#
#
#             var marker_9576f58d8a1c5edca4ca04d898aec170 = L.marker(
#                 [52.519355, 13.428726],
#                 {}
#             ).addTo(map_791d3ab10d270449c0f4881446d9c7c1);
#
#
#         var popup_cfb3e6a4e79a2e94d77a4fff6bb1aceb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c97412533fff64979a3fa7007a9705ef = $(`&lt;div id=&quot;html_c97412533fff64979a3fa7007a9705ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 2&lt;/div&gt;`)[0];
#                 popup_cfb3e6a4e79a2e94d77a4fff6bb1aceb.setContent(html_c97412533fff64979a3fa7007a9705ef);
#
#
#
#         marker_9576f58d8a1c5edca4ca04d898aec170.bindPopup(popup_cfb3e6a4e79a2e94d77a4fff6bb1aceb)
#         ;
#
#
#
#
#             var marker_581c9dda1bba965245b1e5c3e19fc459 = L.marker(
#                 [52.496369, 13.374825],
#                 {}
#             ).addTo(map_791d3ab10d270449c0f4881446d9c7c1);
#
#
#         var popup_b25faf8e660d3e2539ca4c55700e54fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc50a2284098534094c061673416a34e = $(`&lt;div id=&quot;html_cc50a2284098534094c061673416a34e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 3&lt;/div&gt;`)[0];
#                 popup_b25faf8e660d3e2539ca4c55700e54fd.setContent(html_cc50a2284098534094c061673416a34e);
#
#
#
#         marker_581c9dda1bba965245b1e5c3e19fc459.bindPopup(popup_b25faf8e660d3e2539ca4c55700e54fd)
#         ;
#
#
#
#
#             var marker_dcdfb5e5bf047285caf9c922ff795cfa = L.marker(
#                 [52.533558, 13.384116],
#                 {}
#             ).addTo(map_791d3ab10d270449c0f4881446d9c7c1);
#
#
#         var popup_f199fb31863b1a919d89dd8082045b4d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3485c0aaca02d6dad07efa602f32f580 = $(`&lt;div id=&quot;html_3485c0aaca02d6dad07efa602f32f580&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 4&lt;/div&gt;`)[0];
#                 popup_f199fb31863b1a919d89dd8082045b4d.setContent(html_3485c0aaca02d6dad07efa602f32f580);
#
#
#
#         marker_dcdfb5e5bf047285caf9c922ff795cfa.bindPopup(popup_f199fb31863b1a919d89dd8082045b4d)
#         ;

# %%
steps_list = route['features'][0]['properties']['segments'][0]['steps']
steps_list
# Out:
# [{'distance': 129.0,
#   'duration': 92.9,
#   'type': 11,
#   'instruction': 'Head southeast',
#   'name': '-',
#   'way_points': [0, 4]},
#  {'distance': 3.9,
#   'duration': 2.8,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [4, 5]},
#  {'distance': 30.0,
#   'duration': 21.6,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [5, 10]},
#  {'distance': 109.4,
#   'duration': 78.8,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [10, 13]},
#  {'distance': 4.5,
#   'duration': 3.2,
#   'type': 3,
#   'instruction': 'Turn sharp right',
#   'name': '-',
#   'way_points': [13, 15]},
#  {'distance': 12.2,
#   'duration': 8.8,
#   'type': 2,
#   'instruction': 'Turn sharp left',
#   'name': '-',
#   'way_points': [15, 17]},
#  {'distance': 5.1,
#   'duration': 3.7,
#   'type': 0,
#   'instruction': 'Turn left onto Invalidenstraße',
#   'name': 'Invalidenstraße',
#   'way_points': [17, 18]},
#  {'distance': 21.7,
#   'duration': 15.6,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [18, 22]},
#  {'distance': 16.6,
#   'duration': 12.0,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [22, 24]},
#  {'distance': 16.1,
#   'duration': 11.6,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [24, 26]},
#  {'distance': 192.0,
#   'duration': 138.2,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [26, 35]},
#  {'distance': 7.1,
#   'duration': 5.1,
#   'type': 12,
#   'instruction': 'Keep left',
#   'name': '-',
#   'way_points': [35, 36]},
#  {'distance': 455.4,
#   'duration': 327.9,
#   'type': 1,
#   'instruction': 'Turn right onto Gartenstraße',
#   'name': 'Gartenstraße',
#   'way_points': [36, 57]},
#  {'distance': 7.5,
#   'duration': 5.4,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [57, 58]},
#  {'distance': 83.4,
#   'duration': 60.0,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [58, 61]},
#  {'distance': 157.4,
#   'duration': 113.4,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [61, 65]},
#  {'distance': 153.8,
#   'duration': 110.7,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [65, 71]},
#  {'distance': 6.5,
#   'duration': 4.6,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [71, 72]},
#  {'distance': 5.2,
#   'duration': 3.7,
#   'type': 1,
#   'instruction': 'Turn right onto Koppenplatz',
#   'name': 'Koppenplatz',
#   'way_points': [72, 73]},
#  {'distance': 6.1,
#   'duration': 4.4,
#   'type': 0,
#   'instruction': 'Turn left onto Auguststraße',
#   'name': 'Auguststraße',
#   'way_points': [73, 74]},
#  {'distance': 6.3,
#   'duration': 4.5,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [74, 75]},
#  {'distance': 50.7,
#   'duration': 36.5,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [75, 76]},
#  {'distance': 9.1,
#   'duration': 6.5,
#   'type': 13,
#   'instruction': 'Keep right',
#   'name': '-',
#   'way_points': [76, 77]},
#  {'distance': 4.4,
#   'duration': 3.2,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [77, 78]},
#  {'distance': 339.1,
#   'duration': 244.1,
#   'type': 1,
#   'instruction': 'Turn right onto Gipsstraße',
#   'name': 'Gipsstraße',
#   'way_points': [78, 93]},
#  {'distance': 7.9,
#   'duration': 5.7,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [93, 94]},
#  {'distance': 207.1,
#   'duration': 149.1,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [94, 98]},
#  {'distance': 10.1,
#   'duration': 7.2,
#   'type': 4,
#   'instruction': 'Turn slight left',
#   'name': '-',
#   'way_points': [98, 101]},
#  {'distance': 15.4,
#   'duration': 11.1,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [101, 105]},
#  {'distance': 4.1,
#   'duration': 3.0,
#   'type': 5,
#   'instruction': 'Turn slight right',
#   'name': '-',
#   'way_points': [105, 106]},
#  {'distance': 229.3,
#   'duration': 165.1,
#   'type': 4,
#   'instruction': 'Turn slight left',
#   'name': '-',
#   'way_points': [106, 120]},
#  {'distance': 20.5,
#   'duration': 14.8,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [120, 122]},
#  {'distance': 20.7,
#   'duration': 14.9,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [122, 123]},
#  {'distance': 153.5,
#   'duration': 110.5,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [123, 132]},
#  {'distance': 364.5,
#   'duration': 262.4,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [132, 149]},
#  {'distance': 2.2,
#   'duration': 1.6,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [149, 150]},
#  {'distance': 45.6,
#   'duration': 32.8,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [150, 158]},
#  {'distance': 5.8,
#   'duration': 4.2,
#   'type': 1,
#   'instruction': 'Turn right',
#   'name': '-',
#   'way_points': [158, 159]},
#  {'distance': 87.0,
#   'duration': 62.6,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [159, 163]},
#  {'distance': 18.0,
#   'duration': 13.0,
#   'type': 0,
#   'instruction': 'Turn left',
#   'name': '-',
#   'way_points': [163, 164]},
#  {'distance': 46.9,
#   'duration': 33.8,
#   'type': 5,
#   'instruction': 'Turn slight right',
#   'name': '-',
#   'way_points': [164, 166]},
#  {'distance': 216.5,
#   'duration': 155.9,
#   'type': 1,
#   'instruction': 'Turn right onto Karl-Marx-Allee',
#   'name': 'Karl-Marx-Allee',
#   'way_points': [166, 175]},
#  {'distance': 140.8,
#   'duration': 101.4,
#   'type': 12,
#   'instruction': 'Keep left',
#   'name': '-',
#   'way_points': [175, 181]},
#  {'distance': 5.8,
#   'duration': 4.1,
#   'type': 1,
#   'instruction': 'Turn right onto Berolinastraße',
#   'name': 'Berolinastraße',
#   'way_points': [181, 182]},
#  {'distance': 377.7,
#   'duration': 272.0,
#   'type': 0,
#   'instruction': 'Turn left onto Weydemeyerstraße',
#   'name': 'Weydemeyerstraße',
#   'way_points': [182, 196]},
#  {'distance': 13.8,
#   'duration': 9.9,
#   'type': 1,
#   'instruction': 'Turn right onto Lichtenberger Straße',
#   'name': 'Lichtenberger Straße',
#   'way_points': [196, 197]},
#  {'distance': 0.0,
#   'duration': 0.0,
#   'type': 10,
#   'instruction': 'Arrive at Lichtenberger Straße, on the right',
#   'name': '-',
#   'way_points': [197, 197]}]

# %%
steps_df = pd.DataFrame(steps_list)
steps_df
# steps_list
# Out:
#     distance  duration  type                                   instruction  \
# 0      129.0      92.9    11                                Head southeast
# 1        3.9       2.8     0                                     Turn left
# 2       30.0      21.6     1                                    Turn right
# 3      109.4      78.8     1                                    Turn right
# 4        4.5       3.2     3                              Turn sharp right
# 5       12.2       8.8     2                               Turn sharp left
# 6        5.1       3.7     0                Turn left onto Invalidenstraße
# 7       21.7      15.6     1                                    Turn right
# 8       16.6      12.0     0                                     Turn left
# 9       16.1      11.6     0                                     Turn left
# 10     192.0     138.2     0                                     Turn left
# 11       7.1       5.1    12                                     Keep left
# 12     455.4     327.9     1                  Turn right onto Gartenstraße
# 13       7.5       5.4     0                                     Turn left
# 14      83.4      60.0     1                                    Turn right
# 15     157.4     113.4     0                                     Turn left
# 16     153.8     110.7     1                                    Turn right
# 17       6.5       4.6     0                                     Turn left
# 18       5.2       3.7     1                   Turn right onto Koppenplatz
# 19       6.1       4.4     0                   Turn left onto Auguststraße
# 20       6.3       4.5     1                                    Turn right
# 21      50.7      36.5     0                                     Turn left
# 22       9.1       6.5    13                                    Keep right
# 23       4.4       3.2     0                                     Turn left
# 24     339.1     244.1     1                    Turn right onto Gipsstraße
# 25       7.9       5.7     0                                     Turn left
# 26     207.1     149.1     1                                    Turn right
# 27      10.1       7.2     4                              Turn slight left
# 28      15.4      11.1     1                                    Turn right
# 29       4.1       3.0     5                             Turn slight right
# 30     229.3     165.1     4                              Turn slight left
# 31      20.5      14.8     1                                    Turn right
# 32      20.7      14.9     0                                     Turn left
# 33     153.5     110.5     1                                    Turn right
# 34     364.5     262.4     1                                    Turn right
# 35       2.2       1.6     0                                     Turn left
# 36      45.6      32.8     1                                    Turn right
# 37       5.8       4.2     1                                    Turn right
# 38      87.0      62.6     0                                     Turn left
# 39      18.0      13.0     0                                     Turn left
# 40      46.9      33.8     5                             Turn slight right
# 41     216.5     155.9     1               Turn right onto Karl-Marx-Allee
# 42     140.8     101.4    12                                     Keep left
# 43       5.8       4.1     1                Turn right onto Berolinastraße
# 44     377.7     272.0     0               Turn left onto Weydemeyerstraße
# 45      13.8       9.9     1          Turn right onto Lichtenberger Straße
# 46       0.0       0.0    10  Arrive at Lichtenberger Straße, on the right
#
#                     name  way_points
# 0                      -      [0, 4]
# 1                      -      [4, 5]
# 2                      -     [5, 10]
# 3                      -    [10, 13]
# 4                      -    [13, 15]
# 5                      -    [15, 17]
# 6        Invalidenstraße    [17, 18]
# 7                      -    [18, 22]
# 8                      -    [22, 24]
# 9                      -    [24, 26]
# 10                     -    [26, 35]
# 11                     -    [35, 36]
# 12          Gartenstraße    [36, 57]
# 13                     -    [57, 58]
# 14                     -    [58, 61]
# 15                     -    [61, 65]
# 16                     -    [65, 71]
# 17                     -    [71, 72]
# 18           Koppenplatz    [72, 73]
# 19          Auguststraße    [73, 74]
# 20                     -    [74, 75]
# 21                     -    [75, 76]
# 22                     -    [76, 77]
# 23                     -    [77, 78]
# 24            Gipsstraße    [78, 93]
# 25                     -    [93, 94]
# 26                     -    [94, 98]
# 27                     -   [98, 101]
# 28                     -  [101, 105]
# 29                     -  [105, 106]
# 30                     -  [106, 120]
# 31                     -  [120, 122]
# 32                     -  [122, 123]
# 33                     -  [123, 132]
# 34                     -  [132, 149]
# 35                     -  [149, 150]
# 36                     -  [150, 158]
# 37                     -  [158, 159]
# 38                     -  [159, 163]
# 39                     -  [163, 164]
# 40                     -  [164, 166]
# 41       Karl-Marx-Allee  [166, 175]
# 42                     -  [175, 181]
# 43        Berolinastraße  [181, 182]
# 44      Weydemeyerstraße  [182, 196]
# 45  Lichtenberger Straße  [196, 197]
# 46                     -  [197, 197]

# %% [markdown]
# ### Find round trips with n Steps

# %%
coordinates = [[13.384116, 52.533558], [13.41774, 52.498929], [13.428726, 52.519355], [13.374825, 52.496369], [13.384116, 52.533558]]
index_list = [0,1,2,3,0]

# %%
import itertools
permutations = list(itertools.permutations(index_list[1:-1]))
new_permutations = []
for el in permutations:
    el_list = [i for i in el]
    new_permutations.append([0]+ el_list+ [0])
new_permutations
# permutations
# Out:
# [[0, 1, 2, 3, 0],
#  [0, 1, 3, 2, 0],
#  [0, 2, 1, 3, 0],
#  [0, 2, 3, 1, 0],
#  [0, 3, 1, 2, 0],
#  [0, 3, 2, 1, 0]]

# %%
coordinates_permuted = []

for index,el in enumerate(new_permutations):
    new_coords = []
    for i in new_permutations[index]:
        new_coords.append(coordinates[i])
    coordinates_permuted.append(new_coords)

# %%
new_permutations[1]
# Out:
# [0, 1, 3, 2, 0]

# %%
coordinates_permuted[1]
# Out:
# [[13.384116, 52.533558],
#  [13.41774, 52.498929],
#  [13.374825, 52.496369],
#  [13.428726, 52.519355],
#  [13.384116, 52.533558]]

# %%
def get_round_trip(coordinates, index_list):
    route_list = []
    route_summary_list = []
    for step_index in range (1, len(index_list)):
        print(f'\tnode {index_list[step_index-1]}: {coordinates[step_index-1]} \t| node {index_list[step_index]}: {coordinates[step_index]}')
        route = client.directions(
            coordinates=[coordinates[step_index-1], coordinates[step_index]],
            profile=profile_car,
            format='geojson',
            validate=False,
        )
        route_list.append(route)
        route_summary_list.append({
            'index': index_list[step_index],
            'distance': route['features'][0]['properties']['segments'][0]['distance'],
            'duration': route['features'][0]['properties']['segments'][0]['duration'],
        })

    return route_list, pd.DataFrame(route_summary_list)

# %%
route_list, route_sum_df = get_round_trip(coordinates= coordinates, index_list=index_list)
# Out:
# node 0: [13.384116, 52.533558] 	| node 1: [13.41774, 52.498929]
# node 1: [13.41774, 52.498929] 	| node 2: [13.428726, 52.519355]
# node 2: [13.428726, 52.519355] 	| node 3: [13.374825, 52.496369]
# node 3: [13.374825, 52.496369] 	| node 0: [13.384116, 52.533558]

# %%
route_summary_list = []
for idx, el in enumerate(route_list):
    route_summary_list.append({
        'index': idx,
        'distance': el['features'][0]['properties']['segments'][0]['distance'],
        'duration': el['features'][0]['properties']['segments'][0]['duration'],
    })
route_summary_list
# Out:
# [{'index': 0, 'distance': 7884.4, 'duration': 985.3},
#  {'index': 1, 'distance': 3037.7, 'duration': 521.1},
#  {'index': 2, 'distance': 6234.4, 'duration': 843.3},
#  {'index': 3, 'distance': 5196.7, 'duration': 657.8}]

# %%
route_summary_df = pd.DataFrame(route_summary_list)
route_summary_df
# Out:
#    index  distance  duration
# 0      0    7884.4     985.3
# 1      1    3037.7     521.1
# 2      2    6234.4     843.3
# 3      3    5196.7     657.8

# %%
print(route_sum_df)
# Out:
#    index  distance  duration
# 0      1    7884.4     985.3
# 1      2    3037.7     521.1
# 2      3    6234.4     843.3
# 3      0    5196.7     657.8

# %%
def get_coords_and_index_list_permutations(
    coordinates: list,
    index_list: list
):
    index_permutations = list(itertools.permutations(index_list[1:-1]))
    new_permutations = []
    for el in index_permutations:
        el_list = [i for i in el]
        new_permutations.append([0]+ el_list+ [0])
    
    coordinates_permuted = []

    for idx, el in enumerate(new_permutations):
        new_coords = []
        for i in new_permutations[idx]:
            new_coords.append(coordinates[i])
        coordinates_permuted.append(new_coords)
    return coordinates_permuted, new_permutations

# %%
coordinates_permuted, index_permuted = get_coords_and_index_list_permutations(
    coordinates= coordinates,
    index_list= [0,1,2,3,0]
)

# %%
permutations_route_list = []

for idx, el in enumerate(index_permuted):
    print(f'index: {idx}, index_permuted: {index_permuted[idx]}, coords_permuted: {coordinates_permuted[idx]} ')
    route_list, route_sum_df = get_round_trip(coordinates= coordinates_permuted[idx], index_list=index_permuted[idx])
    permutations_route_list.append(
        {
            'index': idx,
            'route_list': route_list,
            'route_sum_df': route_sum_df
        }
    )
# Out:
# index: 0, index_permuted: [0, 1, 2, 3, 0], coords_permuted: [[13.384116, 52.533558], [13.41774, 52.498929], [13.428726, 52.519355], [13.374825, 52.496369], [13.384116, 52.533558]]
# 	node 0: [13.384116, 52.533558] 	| node 1: [13.41774, 52.498929]
# 	node 1: [13.41774, 52.498929] 	| node 2: [13.428726, 52.519355]
# 	node 2: [13.428726, 52.519355] 	| node 3: [13.374825, 52.496369]
# 	node 3: [13.374825, 52.496369] 	| node 0: [13.384116, 52.533558]
# index: 1, index_permuted: [0, 1, 3, 2, 0], coords_permuted: [[13.384116, 52.533558], [13.41774, 52.498929], [13.374825, 52.496369], [13.428726, 52.519355], [13.384116, 52.533558]]
# 	node 0: [13.384116, 52.533558] 	| node 1: [13.41774, 52.498929]
# 	node 1: [13.41774, 52.498929] 	| node 3: [13.374825, 52.496369]
# 	node 3: [13.374825, 52.496369] 	| node 2: [13.428726, 52.519355]
# 	node 2: [13.428726, 52.519355] 	| node 0: [13.384116, 52.533558]
# index: 2, index_permuted: [0, 2, 1, 3, 0], coords_permuted: [[13.384116, 52.533558], [13.428726, 52.519355], [13.41774, 52.498929], [13.374825, 52.496369], [13.384116, 52.533558]]
# 	node 0: [13.384116, 52.533558] 	| node 2: [13.428726, 52.519355]
# 	node 2: [13.428726, 52.519355] 	| node 1: [13.41774, 52.498929]
# 	node 1: [13.41774, 52.498929] 	| node 3: [13.374825, 52.496369]
# 	node 3: [13.374825, 52.496369] 	| node 0: [13.384116, 52.533558]
# index: 3, index_permuted: [0, 2, 3, 1, 0], coords_permuted: [[13.384116, 52.533558], [13.428726, 52.519355], [13.374825, 52.496369], [13.41774, 52.498929], [13.384116, 52.533558]]
# 	node 0: [13.384116, 52.533558] 	| node 2: [13.428726, 52.519355]
# 	node 2: [13.428726, 52.519355] 	| node 3: [13.374825, 52.496369]
# 	node 3: [13.374825, 52.496369] 	| node 1: [13.41774, 52.498929]
# 	node 1: [13.41774, 52.498929] 	| node 0: [13.384116, 52.533558]
# index: 4, index_permuted: [0, 3, 1, 2, 0], coords_permuted: [[13.384116, 52.533558], [13.374825, 52.496369], [13.41774, 52.498929], [13.428726, 52.519355], [13.384116, 52.533558]]
# 	node 0: [13.384116, 52.533558] 	| node 3: [13.374825, 52.496369]
# 	node 3: [13.374825, 52.496369] 	| node 1: [13.41774, 52.498929]
# 	node 1: [13.41774, 52.498929] 	| node 2: [13.428726, 52.519355]
# 	node 2: [13.428726, 52.519355] 	| node 0: [13.384116, 52.533558]
# index: 5, index_permuted: [0, 3, 2, 1, 0], coords_permuted: [[13.384116, 52.533558], [13.374825, 52.496369], [13.428726, 52.519355], [13.41774, 52.498929], [13.384116, 52.533558]]
# 	node 0: [13.384116, 52.533558] 	| node 3: [13.374825, 52.496369]
# 	node 3: [13.374825, 52.496369] 	| node 2: [13.428726, 52.519355]
# 	node 2: [13.428726, 52.519355] 	| node 1: [13.41774, 52.498929]
# 	node 1: [13.41774, 52.498929] 	| node 0: [13.384116, 52.533558]

# %%
permutations_route_list[0]['route_sum_df']
# Out:
#    index  distance  duration
# 0      1    7884.4     985.3
# 1      2    3037.7     521.1
# 2      3    6234.4     843.3
# 3      0    5196.7     657.8

# %% [markdown]
# ### Matrix
# * distances of every node to start/end point

# %%
m = folium.Map(location=[52.521861, 13.40744], tiles='cartodbpositron', zoom_start=13)

# Some coordinates in Berlin
coordinates = [[13.384116, 52.533558], [13.428726, 52.519355], [13.41774, 52.498929], [13.374825, 52.496369]]

matrix = client.distance_matrix(
    locations=coordinates,
    profile=profile_car,
    metrics=['distance', 'duration'],
    validate=False,
)

for marker in coordinates:
    folium.Marker(location=list(reversed(marker))).add_to(m)

print("Durations in secs: {}\n".format(matrix['durations']))
print("Distances in m: {}".format(matrix['distances']))

m
# Out:
# Durations in secs: [[0.0, 663.22, 985.28, 691.28], [647.47, 0.0, 514.75, 843.28], [905.03, 521.11, 0.0, 503.28], [657.76, 833.93, 513.01, 0.0]]
#
# Distances in m: [[0.0, 4044.07, 7884.37, 5455.42], [4071.65, 0.0, 2716.73, 6234.41], [7755.53, 3037.68, 0.0, 4007.69], [5196.67, 5953.24, 3753.86, 0.0]]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_723a9f5b24aa76e8019de46956581bc3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_723a9f5b24aa76e8019de46956581bc3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_723a9f5b24aa76e8019de46956581bc3 = L.map(
#                 &quot;map_723a9f5b24aa76e8019de46956581bc3&quot;,
#                 {
#                     center: [52.521861, 13.40744],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a868019a2c784f82c46e7cba7abbb99 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_723a9f5b24aa76e8019de46956581bc3);
#
#
#             var marker_846677a0d9c54d25077f2193c2e33ef2 = L.marker(
#                 [52.533558, 13.384116],
#                 {}
#             ).addTo(map_723a9f5b24aa76e8019de46956581bc3);
#
#
#             var marker_444aadc92e830d48a8ecc8aecd1af0c4 = L.marker(
#                 [52.519355, 13.428726],
#                 {}
#             ).addTo(map_723a9f5b24aa76e8019de46956581bc3);
#
#
#             var marker_16c8071e78430d73faf489129f4766ee = L.marker(
#                 [52.498929, 13.41774],
#                 {}
#             ).addTo(map_723a9f5b24aa76e8019de46956581bc3);
#
#
#             var marker_bac4aa76d7b4c470323a038d29686ee5 = L.marker(
#                 [52.496369, 13.374825],
#                 {}
#             ).addTo(map_723a9f5b24aa76e8019de46956581bc3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
matrix
# Out:
# {'durations': [[0.0, 663.22, 985.28, 691.28],
#   [647.47, 0.0, 514.75, 843.28],
#   [905.03, 521.11, 0.0, 503.28],
#   [657.76, 833.93, 513.01, 0.0]],
#  'distances': [[0.0, 4044.07, 7884.37, 5455.42],
#   [4071.65, 0.0, 2716.73, 6234.41],
#   [7755.53, 3037.68, 0.0, 4007.69],
#   [5196.67, 5953.24, 3753.86, 0.0]],
#  'destinations': [{'location': [13.38395, 52.533489],
#    'snapped_distance': 13.61},
#   {'location': [13.428816, 52.519341], 'snapped_distance': 6.3},
#   {'location': [13.417828, 52.498956], 'snapped_distance': 6.69},
#   {'location': [13.37311, 52.497606], 'snapped_distance': 179.97}],
#  'sources': [{'location': [13.38395, 52.533489], 'snapped_distance': 13.61},
#   {'location': [13.428816, 52.519341], 'snapped_distance': 6.3},
#   {'location': [13.417828, 52.498956], 'snapped_distance': 6.69},
#   {'location': [13.37311, 52.497606], 'snapped_distance': 179.97}],
#  'metadata': {'attribution': 'openrouteservice.org | OpenStreetMap contributors',
#   'service': 'matrix',
#   'timestamp': 1686586414931,
#   'query': {'locations': [[13.384116, 52.533558],
#     [13.428726, 52.519355],
#     [13.41774, 52.498929],
#     [13.374825, 52.496369]],
#    'profile': 'driving-car',
#    'responseType': 'json',
#    'metrics': ['distance', 'duration']},
#   'engine': {'version': '6.8.1',
#    'build_date': '2023-05-22T14:27:28Z',
#    'graph_date': '2023-06-04T15:57:08Z'}}}
